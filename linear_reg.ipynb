# %%
#import numpy as np
# %pip install numpy statsmodels
# Out:
# ...
#   Using cached numpy-2.4.0-cp313-cp313-win_amd64.whl.metadata (6.6 kB)
# ...
#   Using cached scipy-1.16.3-cp313-cp313-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached pandas-2.3.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached numpy-2.4.0-cp313-cp313-win_amd64.whl (12.3 MB)
# ...
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.5 MB 1.5 MB/s eta 0:00:06
#    --- ------------------------------------ 0.8/9.5 MB 1.5 MB/s eta 0:00:06
#    ---- ----------------------------------- 1.0/9.5 MB 1.5 MB/s eta 0:00:06
#    ----- ---------------------------------- 1.3/9.5 MB 1.4 MB/s eta 0:00:06
#    ------ --------------------------------- 1.6/9.5 MB 1.4 MB/s eta 0:00:06
# ...

# %%
import numpy as np
import statsmodels.api as sm

# %%
# Data
Age = np.array([5, 4, 6, 5, 5, 5, 6, 6, 2, 7, 7])
Km = np.array([92, 64, 124, 97, 79, 76, 93, 63, 13, 111, 143])
Price = np.array([7.8, 9.5, 6.4, 7.5, 8.1, 9, 6.1, 8.7, 15.4, 6.4, 4.4])
# Prepare the data for regression
print(f"Number of observations: n = {len(Price)}")
print(f"Number of predictors: p = 2 (Age, Mileage)")
print(f"Data dimensions check: n > p? {len(Price) > 2} ✓")
# Out:
# Number of observations: n = 11
# Number of predictors: p = 2 (Age, Mileage)
# Data dimensions check: n > p? True ✓
